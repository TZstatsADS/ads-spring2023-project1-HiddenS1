# %% [markdown]
# ### output of topic modeling on sentences before 250

# %%
[(0,
  '0.012*"water" + 0.010*"parts" + 0.008*"air" + 0.007*"well" + 0.007*"cannot" '
  '+ 0.007*"earth" + 0.007*"nature" + 0.007*"whole" + 0.006*"fire" + '
  '0.005*"know"'),
 (1,
  '0.012*"socrates" + 0.008*"kind" + 0.007*"mean" + 0.007*"time" + '
  '0.006*"genus" + 0.006*"people" + 0.006*"nature" + 0.006*"others" + '
  '0.005*"number" + 0.005*"well"'),
 (2,
  '0.011*"substance" + 0.007*"possible" + 0.006*"know" + 0.006*"see" + '
  '0.006*"power" + 0.006*"shall" + 0.006*"others" + 0.005*"thought" + '
  '0.005*"equal" + 0.005*"belongs"'),
 (3,
  '0.008*"every" + 0.005*"life" + 0.005*"possible" + 0.004*"people" + '
  '0.004*"let" + 0.004*"clear" + 0.004*"right" + 0.004*"person" + 0.004*"know" '
  '+ 0.004*"without"'),
 (4,
  '0.006*"sometimes" + 0.006*"called" + 0.006*"well" + 0.005*"movement" + '
  '0.004*"come" + 0.004*"shall" + 0.004*"weight" + 0.004*"fact" + 0.004*"bad" '
  '+ 0.004*"among"'),
 (5,
  '0.011*"different" + 0.009*"time" + 0.009*"knowledge" + 0.008*"point" + '
  '0.008*"true" + 0.006*"right" + 0.005*"others" + 0.005*"sense" + 0.005*"let" '
  '+ 0.004*"soul"'),
 (6,
  '0.007*"love" + 0.007*"male" + 0.007*"motion" + 0.006*"female" + '
  '0.006*"well" + 0.006*"take" + 0.005*"nature" + 0.005*"universal" + '
  '0.004*"form" + 0.004*"place"'),
 (7,
  '0.011*"time" + 0.007*"come" + 0.007*"place" + 0.006*"without" + '
  '0.005*"white" + 0.005*"contrary" + 0.004*"socrates" + 0.004*"better" + '
  '0.004*"contraries" + 0.004*"animals"'),
 (8,
  '0.013*"animals" + 0.011*"others" + 0.009*"property" + 0.007*"number" + '
  '0.007*"parts" + 0.007*"body" + 0.006*"every" + 0.006*"kind" + '
  '0.006*"always" + 0.005*"necessary"'),
 (9,
  '0.008*"soul" + 0.007*"see" + 0.007*"body" + 0.007*"people" + '
  '0.007*"nothing" + 0.005*"conclusion" + 0.004*"call" + 0.004*"negative" + '
  '0.004*"true" + 0.004*"different"')]

# %% [markdown]
# ### output of topic modeling on sentences after 500

# %%
[(0,
  '0.009*"woman" + 0.008*"love" + 0.006*"women" + 0.006*"form" + '
  '0.005*"relation" + 0.005*"life" + 0.004*"class" + 0.004*"person" + '
  '0.004*"see" + 0.004*"rent"'),
 (1,
  '0.011*"time" + 0.011*"object" + 0.008*"woman" + 0.007*"body" + '
  '0.006*"quantity" + 0.005*"subject" + 0.005*"without" + 0.005*"objects" + '
  '0.005*"space" + 0.005*"infinite"'),
 (2,
  '0.009*"great" + 0.008*"trade" + 0.007*"reason" + 0.006*"world" + '
  '0.005*"truth" + 0.005*"without" + 0.004*"language" + 0.004*"finally" + '
  '0.004*"nature" + 0.004*"objective"'),
 (3,
  '0.013*"women" + 0.011*"price" + 0.007*"power" + 0.006*"labour" + '
  '0.005*"theory" + 0.005*"money" + 0.004*"nature" + 0.004*"surplus" + '
  '0.004*"without" + 0.004*"analysis"'),
 (4,
  '0.014*"world" + 0.009*"time" + 0.008*"black" + 0.007*"different" + '
  '0.005*"possible" + 0.005*"value" + 0.005*"unity" + 0.004*"day" + '
  '0.004*"commodity" + 0.004*"conditions"'),
 (5,
  '0.009*"present" + 0.007*"empirical" + 0.007*"existence" + '
  '0.006*"consciousness" + 0.006*"time" + 0.005*"object" + 0.005*"never" + '
  '0.005*"idea" + 0.005*"without" + 0.005*"form"'),
 (6,
  '0.013*"capital" + 0.007*"nothing" + 0.006*"movement" + 0.006*"whole" + '
  '0.005*"example" + 0.005*"value" + 0.005*"however" + 0.004*"within" + '
  '0.004*"labour" + 0.004*"working"'),
 (7,
  '0.016*"concept" + 0.009*"nature" + 0.006*"concepts" + 0.006*"meaning" + '
  '0.006*"cannot" + 0.006*"fact" + 0.005*"law" + 0.005*"women" + 0.004*"level" '
  '+ 0.004*"always"'),
 (8,
  '0.010*"knowledge" + 0.007*"true" + 0.006*"self" + 0.005*"question" + '
  '0.005*"thou" + 0.005*"general" + 0.005*"sense" + 0.004*"rather" + '
  '0.004*"means" + 0.004*"values"'),
 (9,
  '0.008*"self" + 0.008*"woman" + 0.008*"wages" + 0.005*"form" + 0.005*"tax" + '
  '0.005*"de" + 0.005*"truth" + 0.005*"science" + 0.004*"life" + 0.004*"corn"')]

# %% [markdown]
# ### the dominant topic and its percentage of sentences before 250

# %% [markdown]
# ![table1.png](attachment:table1.png)

# %% [markdown]
# ### the most representative sentence for each topic before 250

# %% [markdown]
# ![1675231983%281%29.png](attachment:1675231983%281%29.png)

# %% [markdown]
# ### the dominant topic and its percentage of sentences after 1500

# %% [markdown]
# ![table2.png](attachment:table2.png)

# %% [markdown]
# ### the most representative sentence for each topic after 1500

# %% [markdown]
# ![1675232019%281%29.png](attachment:1675232019%281%29.png)

# %% [markdown]
# ### sentiment analysis for philosophers before 250

# %% [markdown]
# ![sentibef.png](attachment:sentibef.png)

# %% [markdown]
# ### sentiment analysis for philosophers after 1500

# %% [markdown]
# ![sentiaft.png](attachment:sentiaft.png)
